# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def random_walk(n):
  

    x, y,steps = 0, 0, 0
    z = 0;
    Xvals = np.zeros([n,2])
    for j in range(n):
        (dx,dy) = random.choice([(0, 1), (0, -1), (1,0), (-1, 0)])
        x = x + dx
        y = y + dy
        steps = steps + 1
 
        if x == 1001:
            x = 1
        if x == -1:
            x = 999
        if y == 1001:
            y = 1
        if y == -1:
            y = 999


        if x == 10 and y == 0 and z < 1: #location of E2
            z = 1
            print('Successful! A+E2 -> B completed in', str(steps), 'steps')

        Xvals[i,:] = [x,y] #Stores the path of the random walk

        if x == 20 and y == 0: #coordinate of E3
            if z == 0:
                print('Walk ', str(i+1), ' completed in ',
str(steps), ' steps, A reached E3 before E2. Simulation failed :(')
                print(' ')
                steps = 0
                return (Xvals,steps)
            else:
                print('Successful! B+E3 -> C')
                print('Walk ', str(i+1), ' completed in ',
str(steps), ' steps.')
                print(' ')
                return (Xvals,steps)
    print('Walk ', str(i+1), 'completed in ',
str(steps), ' steps, no reaction')

    return (Xvals,steps)

    nsteps = 10000000 #user defined number of steps
    nwalks = 15 #number of walks
    walk =np.zeros([nwalks,nsteps,2])
    count = 0
    time = np.zeros([nwalks])
    for i in range(nwalks):
        (walk[i,:,:], S)= random_walk(nsteps) #for i in range(nwalks)
        
    count += 1
